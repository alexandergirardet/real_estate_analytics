# %%
from google.cloud import storage
import pandas as pd

# %%
client = storage.Client.from_service_account_json(json_credentials_path='/Users/alexandergirardet/projects/estatewise/real_estate_analytics/development/real-estate-dev-key.json')
bucket_name = "rightmove_storage_dev"

blobs = client.list_blobs(bucket_name, prefix=f"rightmove/raw_data")

all_files = []

for blob in blobs:
    all_files.append(blob.name)

# %% [markdown]
# ### Batch data for processing

# %%
from io import BytesIO

# %%
n = 5
batches = [
    all_files[i : i + n] for i in range(0, len(all_files), n)
]

# %%
files = batches[0]
bucket = client.bucket(bucket_name)

# %%
full_df = pd.DataFrame()
for file in files:
    blob = bucket.blob(file)
    df = pd.read_json(BytesIO(blob.download_as_string()), lines=True)
    # full_df = full_df.append(df)
    full_df = pd.concat([df, full_df], axis=0)

# %%
full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 250 entries, 0 to 49
# Data columns (total 51 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           250 non-null    int64
#  1   bedrooms                     250 non-null    int64
#  2   bathrooms                    234 non-null    float64
#  3   numberOfImages               250 non-null    int64
#  4   numberOfFloorplans           250 non-null    int64
#  5   numberOfVirtualTours         250 non-null    int64
#  6   summary                      250 non-null    object
#  7   displayAddress               250 non-null    object
#  8   countryCode                  250 non-null    object
#  9   location                     250 non-null    object
#  10  propertyImages               250 non-null    object
#  11  propertySubType              250 non-null    object
#  12  listingUpdate                250 non-null    object
#  13  premiumListing               250 non-null    bool
#  14  featuredProperty             250 non-null    bool
#  15  price                        250 non-null    object
#  16  customer                     250 non-null    object
#  17  distance                     0 non-null      float64
#  18  transactionType              250 non-null    object
#  19  productLabel                 250 non-null    object
#  20  commercial                   250 non-null    bool
#  21  development                  250 non-null    bool
#  22  residential                  250 non-null    bool
#  23  students                     250 non-null    bool
#  24  auction                      250 non-null    bool
#  25  feesApply                    250 non-null    bool
#  26  feesApplyText                141 non-null    object
#  27  displaySize                  250 non-null    object
#  28  showOnMap                    250 non-null    bool
#  29  propertyUrl                  250 non-null    object
#  30  contactUrl                   250 non-null    object
#  31  staticMapUrl                 0 non-null      float64
#  32  channel                      250 non-null    object
#  33  firstVisibleDate             250 non-null    object
#  34  keywords                     250 non-null    object
#  35  keywordMatchType             250 non-null    object
#  36  saved                        250 non-null    bool
#  37  hidden                       250 non-null    bool
#  38  onlineViewingsAvailable      250 non-null    bool
#  39  lozengeModel                 250 non-null    object
#  40  hasBrandPlus                 250 non-null    bool
#  41  displayStatus                250 non-null    object
#  42  enquiredTimestamp            0 non-null      float64
#  43  heading                      250 non-null    object
#  44  addedOrReduced               250 non-null    object
#  45  formattedBranchName          250 non-null    object
#  46  formattedDistance            250 non-null    object
#  47  propertyTypeFullDescription  250 non-null    object
#  48  isRecent                     250 non-null    bool
#  49  enhancedListing              250 non-null    bool
#  50  feature_list                 218 non-null    object
# dtypes: bool(15), float64(4), int64(5), object(27)
# memory usage: 75.9+ KB

# %%
import jsonschema

# %%
schema = {
    "type": "object",
    "properties": {
        "name": {"type": "string"},
        "age": {"type": "integer"},
        "email": {"type": "string", "format": "email"}
    },
    "required": ["name", "age"],
    "definitions": {
        "integer": {
            "type": "integer",
            "validator": validate_integer
        }
    }
}

# %%
json_dict = full_df.iloc[0].to_json()

# %%
import json

# %%
data = json.loads(json_dict)

# Create a Draft7Validator instance
validator = jsonschema.Draft7Validator(data)

# Extract the JSON schema
schema = validator.schema

# Print the extracted schema
print(json.dumps(schema, indent=2))
# Out:
# {
#   "id": 131465186,
#   "bedrooms": 1,
#   "bathrooms": 1.0,
#   "numberOfImages": 13,
#   "numberOfFloorplans": 0,
#   "numberOfVirtualTours": 0,
#   "summary": "Peter David are pleased to offer this one bedroom property TO LET in the beautiful Luddenden Valley Luddenden is a conservation area surrounded by the Pennine Hills ideal for walkers Luddenden is served by a local bus route and has a strong community spirit with the Church and the friendly pub acting as focal points for many festivities throughout the year This property would ideally be suited to a single person or a couple Offered unfurnished the property comprises of a lounge, small kitchen, bathroom and one double bedroom The property also has gas central heating and double glazing though out Parking for one smallmedium sized car outside the property Other on street parking available on New Road We recommend an early viewing Pets will be considered Smoking outside pleaseBrochuresThorn View, LuddendenBrochure",
#   "displayAddress": "Thorn View, Luddenden",
#   "countryCode": "GB",
#   "location": {
#     "latitude": 53.731136,
#     "longitude": -1.940605
#   },
#   "propertyImages": {
#     "images": [
#       {
#         "srcUrl": "https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/19k/18527/131465186/18527_32104888_IMG_00_0000_max_476x317.jpeg",
#         "url": "19k/18527/131465186/18527_32104888_IMG_00_0000.jpeg",
#         "caption": "IMG_1382.JPG"
#       },
#       {
#         "srcUrl": "https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/19k/18527/131465186/18527_32104888_IMG_01_0000_max_476x317.jpeg",
#         "url": "19k/18527/131465186/18527_32104888_IMG_01_0000.jpeg",
#         "caption": "18527_PDP111THORNVIE_IMG_03_0000_max_656x437.jpg"
#       },
#       {
#         "srcUrl": "https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/19k/18527/131465186/18527_32104888_IMG_02_0000_max_476x317.jpeg",
#         "url": "19k/18527/131465186/18527_32104888_IMG_02_0000.jpeg",
#         "caption": "18527_PDP111THORNVIE_IMG_04_0000_max_656x437.jpg"
#       },
#       {
#         "srcUrl": "https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/19k/18527/131465186/18527_32104888_IMG_03_0000_max_476x317.jpeg",
#         "url": "19k/18527/131465186/18527_32104888_IMG_03_0000.jpeg",
#         "caption": "18527_PDP111THORNVIE_IMG_05_0000_max_656x437.jpg"
#       },
#       {
#         "srcUrl": "https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/19k/18527/131465186/18527_32104888_IMG_04_0000_max_476x317.jpeg",
#         "url": "19k/18527/131465186/18527_32104888_IMG_04_0000.jpeg",
#         "caption": "18527_PDP111THORNVIE_IMG_06_0000_max_656x437.jpg"
#       },
#       {
#         "srcUrl": "https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/19k/18527/131465186/18527_32104888_IMG_05_0000_max_476x317.jpeg",
#         "url": "19k/18527/131465186/18527_32104888_IMG_05_0000.jpeg",
#         "caption": "18527_PDP111THORNVIE_IMG_07_0000_max_656x437.jpg"
#       },
#       {
#         "srcUrl": "https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/19k/18527/131465186/18527_32104888_IMG_06_0000_max_476x317.jpeg",
#         "url": "19k/18527/131465186/18527_32104888_IMG_06_0000.jpeg",
#         "caption": "18527_PDP111THORNVIE_IMG_09_0000_max_656x437.jpg"
#       },
#       {
#         "srcUrl": "https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/19k/18527/131465186/18527_32104888_IMG_07_0000_max_476x317.jpeg",
#         "url": "19k/18527/131465186/18527_32104888_IMG_07_0000.jpeg",
#         "caption": "18527_PDP111THORNVIE_IMG_10_0000_max_656x437.jpg"
#       },
#       {
#         "srcUrl": "https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/19k/18527/131465186/18527_32104888_IMG_08_0000_max_476x317.jpeg",
#         "url": "19k/18527/131465186/18527_32104888_IMG_08_0000.jpeg",
#         "caption": "18527_PDP111THORNVIE_IMG_11_0000_max_656x437.jpg"
#       },
#       {
#         "srcUrl": "https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/19k/18527/131465186/18527_32104888_IMG_09_0000_max_476x317.jpeg",
#         "url": "19k/18527/131465186/18527_32104888_IMG_09_0000.jpeg",
#         "caption": "18527_PDP111THORNVIE_IMG_12_0000_max_656x437.jpg"
#       },
#       {
#         "srcUrl": "https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/19k/18527/131465186/18527_32104888_IMG_10_0000_max_476x317.jpeg",
#         "url": "19k/18527/131465186/18527_32104888_IMG_10_0000.jpeg",
#         "caption": "IMG_1380.JPG"
#       },
#       {
#         "srcUrl": "https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/19k/18527/131465186/18527_32104888_IMG_11_0000_max_476x317.jpeg",
#         "url": "19k/18527/131465186/18527_32104888_IMG_11_0000.jpeg",
#         "caption": "IMG_1385.JPG"
#       },
#       {
#         "srcUrl": "https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/19k/18527/131465186/18527_32104888_IMG_12_0000_max_476x317.jpeg",
#         "url": "19k/18527/131465186/18527_32104888_IMG_12_0000.jpeg",
#         "caption": "18527_PDP111THORNVIE_IMG_16_0000_max_656x437.jpg"
#       }
#     ],
#     "mainImageSrc": "https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/19k/18527/131465186/18527_32104888_IMG_00_0000_max_476x317.jpeg",
#     "mainMapImageSrc": "https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/19k/18527/131465186/18527_32104888_IMG_00_0000_max_296x197.jpeg"
#   },
#   "propertySubType": "Terraced",
#   "listingUpdate": {
#     "listingUpdateReason": "new",
#     "listingUpdateDate": "2023-02-06T20:03:01Z"
#   },
#   "premiumListing": false,
#   "featuredProperty": false,
#   "price": {
#     "amount": 500,
#     "frequency": "monthly",
#     "currencyCode": "GBP",
#     "displayPrices": [
#       {
#         "displayPrice": "\u00a3500 pcm",
#         "displayPriceQualifier": ""
#       },
#       {
#         "displayPrice": "\u00a3115 pw",
#         "displayPriceQualifier": ""
#       }
#     ]
#   },
#   "customer": {
#     "branchId": 18527,
#     "brandPlusLogoURI": "/company/clogo_7664_0000.gif",
#     "contactTelephone": "01422 366948",
#     "branchDisplayName": "Peter David Properties, Halifax",
#     "branchName": "Halifax",
#     "brandTradingName": "Peter David Properties",
#     "branchLandingPageUrl": "/estate-agents/agent/Peter-David-Properties/Halifax-18527.html",
#     "development": false,
#     "showReducedProperties": true,
#     "commercial": false,
#     "showOnMap": true,
#     "enhancedListing": false,
#     "developmentContent": null,
#     "buildToRent": false,
#     "buildToRentBenefits": [],
#     "brandPlusLogoUrl": "https://media.rightmove.co.uk:443/dir/company/clogo_7664_0000_max_100x50.gif"
#   },
#   "distance": null,
#   "transactionType": "rent",
#   "productLabel": {
#     "productLabelText": "",
#     "spotlightLabel": false
#   },
#   "commercial": false,
#   "development": false,
#   "residential": true,
#   "students": false,
#   "auction": false,
#   "feesApply": true,
#   "feesApplyText": null,
#   "displaySize": "",
#   "showOnMap": true,
#   "propertyUrl": "/properties/131465186#/?channel=RES_LET",
#   "contactUrl": "/property-to-rent/contactBranch.html?propertyId=131465186",
#   "staticMapUrl": null,
#   "channel": "RENT",
#   "firstVisibleDate": "2023-02-06T19:57:12Z",
#   "keywords": [],
#   "keywordMatchType": "no_keyword",
#   "saved": false,
#   "hidden": false,
#   "onlineViewingsAvailable": false,
#   "lozengeModel": {
#     "matchingLozenges": []
#   },
#   "hasBrandPlus": true,
#   "displayStatus": "",
#   "enquiredTimestamp": null,
#   "heading": "",
#   "addedOrReduced": "Added on 06/02/2023",
#   "formattedBranchName": " by Peter David Properties, Halifax",
#   "formattedDistance": "",
#   "propertyTypeFullDescription": "1 bedroom terraced house",
#   "isRecent": false,
#   "enhancedListing": false,
#   "feature_list": [
#     "OUTSTANDING COUNTRYSIDE VIEWS",
#     "CONSERVATION AREA",
#     "ONE BEDROOM COTTAGE",
#     "OFFERED UNFURNISHED",
#     "GAS CENTRAL HEATING",
#     "PETS CONSIDERED",
#     "EPC BAND C",
#     "COUNCIL TAX BAND A"
#   ]
# }

# %%
schema
# Out:
# {'id': 131465186,
#  'bedrooms': 1,
#  'bathrooms': 1.0,
#  'numberOfImages': 13,
#  'numberOfFloorplans': 0,
#  'numberOfVirtualTours': 0,
#  'summary': 'Peter David are pleased to offer this one bedroom property TO LET in the beautiful Luddenden Valley Luddenden is a conservation area surrounded by the Pennine Hills ideal for walkers Luddenden is served by a local bus route and has a strong community spirit with the Church and the friendly pub acting as focal points for many festivities throughout the year This property would ideally be suited to a single person or a couple Offered unfurnished the property comprises of a lounge, small kitchen, bathroom and one double bedroom The property also has gas central heating and double glazing though out Parking for one smallmedium sized car outside the property Other on street parking available on New Road We recommend an early viewing Pets will be considered Smoking outside pleaseBrochuresThorn View, LuddendenBrochure',
#  'displayAddress': 'Thorn View, Luddenden',
#  'countryCode': 'GB',
#  'location': {'latitude': 53.731136, 'longitude': -1.940605},
#  'propertyImages': {'images': [{'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/19k/18527/131465186/18527_32104888_IMG_00_0000_max_476x317.jpeg',
#     'url': '19k/18527/131465186/18527_32104888_IMG_00_0000.jpeg',
#     'caption': 'IMG_1382.JPG'},
#    {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/19k/18527/131465186/18527_32104888_IMG_01_0000_max_476x317.jpeg',
#     'url': '19k/18527/131465186/18527_32104888_IMG_01_0000.jpeg',
#     'caption': '18527_PDP111THORNVIE_IMG_03_0000_max_656x437.jpg'},
#    {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/19k/18527/131465186/18527_32104888_IMG_02_0000_max_476x317.jpeg',
#     'url': '19k/18527/131465186/18527_32104888_IMG_02_0000.jpeg',
#     'caption': '18527_PDP111THORNVIE_IMG_04_0000_max_656x437.jpg'},
#    {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/19k/18527/131465186/18527_32104888_IMG_03_0000_max_476x317.jpeg',
#     'url': '19k/18527/131465186/18527_32104888_IMG_03_0000.jpeg',
#     'caption': '18527_PDP111THORNVIE_IMG_05_0000_max_656x437.jpg'},
#    {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/19k/18527/131465186/18527_32104888_IMG_04_0000_max_476x317.jpeg',
#     'url': '19k/18527/131465186/18527_32104888_IMG_04_0000.jpeg',
#     'caption': '18527_PDP111THORNVIE_IMG_06_0000_max_656x437.jpg'},
#    {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/19k/18527/131465186/18527_32104888_IMG_05_0000_max_476x317.jpeg',
#     'url': '19k/18527/131465186/18527_32104888_IMG_05_0000.jpeg',
#     'caption': '18527_PDP111THORNVIE_IMG_07_0000_max_656x437.jpg'},
#    {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/19k/18527/131465186/18527_32104888_IMG_06_0000_max_476x317.jpeg',
#     'url': '19k/18527/131465186/18527_32104888_IMG_06_0000.jpeg',
#     'caption': '18527_PDP111THORNVIE_IMG_09_0000_max_656x437.jpg'},
#    {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/19k/18527/131465186/18527_32104888_IMG_07_0000_max_476x317.jpeg',
#     'url': '19k/18527/131465186/18527_32104888_IMG_07_0000.jpeg',
#     'caption': '18527_PDP111THORNVIE_IMG_10_0000_max_656x437.jpg'},
#    {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/19k/18527/131465186/18527_32104888_IMG_08_0000_max_476x317.jpeg',
#     'url': '19k/18527/131465186/18527_32104888_IMG_08_0000.jpeg',
#     'caption': '18527_PDP111THORNVIE_IMG_11_0000_max_656x437.jpg'},
#    {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/19k/18527/131465186/18527_32104888_IMG_09_0000_max_476x317.jpeg',
#     'url': '19k/18527/131465186/18527_32104888_IMG_09_0000.jpeg',
#     'caption': '18527_PDP111THORNVIE_IMG_12_0000_max_656x437.jpg'},
#    {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/19k/18527/131465186/18527_32104888_IMG_10_0000_max_476x317.jpeg',
#     'url': '19k/18527/131465186/18527_32104888_IMG_10_0000.jpeg',
#     'caption': 'IMG_1380.JPG'},
#    {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/19k/18527/131465186/18527_32104888_IMG_11_0000_max_476x317.jpeg',
#     'url': '19k/18527/131465186/18527_32104888_IMG_11_0000.jpeg',
#     'caption': 'IMG_1385.JPG'},
#    {'srcUrl': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/19k/18527/131465186/18527_32104888_IMG_12_0000_max_476x317.jpeg',
#     'url': '19k/18527/131465186/18527_32104888_IMG_12_0000.jpeg',
#     'caption': '18527_PDP111THORNVIE_IMG_16_0000_max_656x437.jpg'}],
#   'mainImageSrc': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/19k/18527/131465186/18527_32104888_IMG_00_0000_max_476x317.jpeg',
#   'mainMapImageSrc': 'https://media.rightmove.co.uk:443/dir/crop/10:9-16:9/19k/18527/131465186/18527_32104888_IMG_00_0000_max_296x197.jpeg'},
#  'propertySubType': 'Terraced',
#  'listingUpdate': {'listingUpdateReason': 'new',
#   'listingUpdateDate': '2023-02-06T20:03:01Z'},
#  'premiumListing': False,
#  'featuredProperty': False,
#  'price': {'amount': 500,
#   'frequency': 'monthly',
#   'currencyCode': 'GBP',
#   'displayPrices': [{'displayPrice': '£500 pcm', 'displayPriceQualifier': ''},
#    {'displayPrice': '£115 pw', 'displayPriceQualifier': ''}]},
#  'customer': {'branchId': 18527,
#   'brandPlusLogoURI': '/company/clogo_7664_0000.gif',
#   'contactTelephone': '01422 366948',
#   'branchDisplayName': 'Peter David Properties, Halifax',
#   'branchName': 'Halifax',
#   'brandTradingName': 'Peter David Properties',
#   'branchLandingPageUrl': '/estate-agents/agent/Peter-David-Properties/Halifax-18527.html',
#   'development': False,
#   'showReducedProperties': True,
#   'commercial': False,
#   'showOnMap': True,
#   'enhancedListing': False,
#   'developmentContent': None,
#   'buildToRent': False,
#   'buildToRentBenefits': [],
#   'brandPlusLogoUrl': 'https://media.rightmove.co.uk:443/dir/company/clogo_7664_0000_max_100x50.gif'},
#  'distance': None,
#  'transactionType': 'rent',
#  'productLabel': {'productLabelText': '', 'spotlightLabel': False},
#  'commercial': False,
#  'development': False,
#  'residential': True,
#  'students': False,
#  'auction': False,
#  'feesApply': True,
#  'feesApplyText': None,
#  'displaySize': '',
#  'showOnMap': True,
#  'propertyUrl': '/properties/131465186#/?channel=RES_LET',
#  'contactUrl': '/property-to-rent/contactBranch.html?propertyId=131465186',
#  'staticMapUrl': None,
#  'channel': 'RENT',
#  'firstVisibleDate': '2023-02-06T19:57:12Z',
#  'keywords': [],
#  'keywordMatchType': 'no_keyword',
#  'saved': False,
#  'hidden': False,
#  'onlineViewingsAvailable': False,
#  'lozengeModel': {'matchingLozenges': []},
#  'hasBrandPlus': True,
#  'displayStatus': '',
#  'enquiredTimestamp': None,
#  'heading': '',
#  'addedOrReduced': 'Added on 06/02/2023',
#  'formattedBranchName': ' by Peter David Properties, Halifax',
#  'formattedDistance': '',
#  'propertyTypeFullDescription': '1 bedroom terraced house',
#  'isRecent': False,
#  'enhancedListing': False,
#  'feature_list': ['OUTSTANDING COUNTRYSIDE VIEWS',
#   'CONSERVATION AREA',
#   'ONE BEDROOM COTTAGE',
#   'OFFERED UNFURNISHED',
#   'GAS CENTRAL HEATING',
#   'PETS CONSIDERED',
#   'EPC BAND C',
#   'COUNCIL TAX BAND A']}
