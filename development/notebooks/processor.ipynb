# %%
from google.cloud import storage
import json
import pandas as pd

# %% [markdown]
# # Process and Transformation pipeline

# %% [markdown]
# fetch_files -> transform files -> load them

# %% [markdown]
# ## Env variables

# %%
json_creds_path = "/Users/alexandergirardet/projects/estatewise/real_estate_analytics/development/real-estate-dev-key.json"
bucket_name = "rightmove_storage_dev"
client = storage.Client.from_service_account_json(json_credentials_path=json_creds_path)

# %% [markdown]
# ## Functions

# %% [markdown]
# ### fetch files

# %%
 def fetch_all_files(delimiter=None):

    blobs = client.list_blobs(bucket_name, prefix=f"rightmove/raw_data/", delimiter=delimiter)

    all_files = []

    for blob in blobs:
        name = blob.name
        all_files.append(name)
    return all_files

# %%
files = fetch_all_files()

# %%
file_id_list = [file.split("/")[-1] for file in files]

# %%
file_id_list
# Out:
# ['04fe45d3-a1dc-47b7-ab8a-7db1e393fa05.json',
#  '140a0a08-6a85-4b66-8859-09008274e091.json',
#  '1ec51a02-9729-4110-bff1-9b8bdc976306.json',
#  '3094a12c-0e2c-410a-9b3e-ae91d3a9d94b.json',
#  '35fd40b9-c165-4e92-8590-d54af6eb6d4b.json',
#  '436a086b-819a-4cb8-a03a-3cc937323f0f.json',
#  '4e9c6ed9-9030-49a0-bc27-8f948af55b65.json',
#  '50d4d296-3adb-46fc-9fba-0f5deafba2a2.json',
#  '596e7849-2eb2-4a5f-908b-ac59db290f75.json',
#  '6d060173-9238-4d7f-b424-97c063fabe1d.json',
#  '7e56578f-5991-4d3f-8a72-e7507501cdbc.json',
#  '83fd30f0-c08c-4adb-8e6a-4e00292b40e7.json',
#  '86a4e58a-8f68-4834-850b-7b5fe257abd5.json',
#  '8cd8cee0-ea11-4b13-980c-625908c33dc9.json',
#  '907c096f-79b7-4b71-a869-8f9a367d0fef.json',
#  '94fbed03-016f-4079-90bf-d3231bbcc6da.json',
#  '9c314476-fafa-448c-97c4-1ca09da569df.json',
#  'a6c34e9c-df4b-4dd0-b23c-568c8979779c.json',
#  'ac568ace-9f07-45d3-a3c8-c2e975444e1e.json',
#  'ae9d43ce-f583-4418-b42c-ef8171d2e575.json',
#  'bb5cdb41-2aa1-4370-af92-034721e2e810.json',
#  'd2c7ddba-0932-4b05-867e-bf5e2c3c2b27.json',
#  'd609f820-d70c-48c8-a048-eb190b267ca1.json',
#  'dc6903f6-0392-4e2e-b147-401cb7866867.json',
#  'df0ef68f-7f96-4ede-a79b-36dede7af942.json',
#  'e05a9337-bf32-4711-8e08-9eefffc58a6d.json',
#  'f60ab2d9-a743-4037-bc97-38d6230d747f.json']

# %% [markdown]
# ### download files

# %%
def download_data(file_name: str) -> object:
    
    bucket = client.bucket(bucket_name)
    file_path = f"rightmove/raw_data/{file_name}"
    
    print(file_path)
    
    blob = bucket.blob(file_path)
    
    json_string = blob.download_as_string()
    json_data = json.loads(json_string)
    
    return json_data

# %%
data = download_data(file_id_list[0])
# Out:
# rightmove/raw_data/04fe45d3-a1dc-47b7-ab8a-7db1e393fa05.json

# %% [markdown]
# ### transform data

# %%
import sys
sys.path.append("..")
from final_transformer import ParquetTransformer

# %%
transformer = ParquetTransformer()

# %%
valid_data, invalid_data = transformer.transform_data(data)
print(len(valid_data))
# transformed_data = transformer.enforce_columns(valid_data)
# Out:
# 50

# %% [markdown]
# ### upload files

# %%
def upload_data(data: object, file_name: str, invalid=False) -> object:
    
    bucket = client.bucket(bucket_name)
    
    if invalid:
        upload_file_path = f"rightmove/invalid_data/{file_name}"
        blob = bucket.blob(upload_file_path)
        json_data = json.dumps(data).encode('utf-8')
        blob.upload_from_string(json_data, content_type='application/json')
    else:
        parquet_file_name = file_name.replace(".json", ".snappy.parquet")
        upload_file_path = f"rightmove/processed_data/{parquet_file_name}"
        blob = bucket.blob(upload_file_path)
        blob.upload_from_string(data.to_parquet(compression='snappy'))
    
    success_flag = True

    return success_flag

# %% [markdown]
# ## Combined

# %%
files = fetch_all_files()
file_names = [file.split("/")[-1] for file in files]

for file_name in file_names:
    data = download_data(file_name)

    valid_data, invalid_data = transformer.transform_data(data)
    
    if len(invalid_data):
        # invalid_df = pd.DataFrame(invalid_data)
        flag = upload_data(invalid_data, file_name, invalid=True)
        print("Invalid Data uploaded")
        
    valid_df = pd.DataFrame(valid_data)
    flag = upload_data(valid_df, file_name, invalid=False)
    print("Transformed Data uploaded")
# Out:
# rightmove/raw_data/04fe45d3-a1dc-47b7-ab8a-7db1e393fa05.json
# Transformed Data uploaded
# rightmove/raw_data/140a0a08-6a85-4b66-8859-09008274e091.json
# Transformed Data uploaded
# rightmove/raw_data/1ec51a02-9729-4110-bff1-9b8bdc976306.json
# Transformed Data uploaded
# rightmove/raw_data/3094a12c-0e2c-410a-9b3e-ae91d3a9d94b.json
# Transformed Data uploaded
# rightmove/raw_data/35fd40b9-c165-4e92-8590-d54af6eb6d4b.json
# Transformed Data uploaded
# rightmove/raw_data/436a086b-819a-4cb8-a03a-3cc937323f0f.json
# Transformed Data uploaded
# rightmove/raw_data/4e9c6ed9-9030-49a0-bc27-8f948af55b65.json
# Invalid Data uploaded
# Transformed Data uploaded
# rightmove/raw_data/50d4d296-3adb-46fc-9fba-0f5deafba2a2.json
# Transformed Data uploaded
# rightmove/raw_data/596e7849-2eb2-4a5f-908b-ac59db290f75.json
# Transformed Data uploaded
# rightmove/raw_data/6d060173-9238-4d7f-b424-97c063fabe1d.json
# Transformed Data uploaded
# rightmove/raw_data/7e56578f-5991-4d3f-8a72-e7507501cdbc.json
# Invalid Data uploaded
# Transformed Data uploaded
# rightmove/raw_data/83fd30f0-c08c-4adb-8e6a-4e00292b40e7.json
# Transformed Data uploaded
# rightmove/raw_data/86a4e58a-8f68-4834-850b-7b5fe257abd5.json
# Transformed Data uploaded
# rightmove/raw_data/8cd8cee0-ea11-4b13-980c-625908c33dc9.json
# Transformed Data uploaded
# rightmove/raw_data/907c096f-79b7-4b71-a869-8f9a367d0fef.json
# Transformed Data uploaded
# rightmove/raw_data/94fbed03-016f-4079-90bf-d3231bbcc6da.json
# Transformed Data uploaded
# rightmove/raw_data/9c314476-fafa-448c-97c4-1ca09da569df.json
# Transformed Data uploaded
# rightmove/raw_data/a6c34e9c-df4b-4dd0-b23c-568c8979779c.json
# Transformed Data uploaded
# rightmove/raw_data/ac568ace-9f07-45d3-a3c8-c2e975444e1e.json
# Transformed Data uploaded
# rightmove/raw_data/ae9d43ce-f583-4418-b42c-ef8171d2e575.json
# Transformed Data uploaded
# rightmove/raw_data/bb5cdb41-2aa1-4370-af92-034721e2e810.json
# Transformed Data uploaded
# rightmove/raw_data/d2c7ddba-0932-4b05-867e-bf5e2c3c2b27.json
# Transformed Data uploaded
# rightmove/raw_data/d609f820-d70c-48c8-a048-eb190b267ca1.json
# Transformed Data uploaded
# rightmove/raw_data/dc6903f6-0392-4e2e-b147-401cb7866867.json
# Transformed Data uploaded
# rightmove/raw_data/df0ef68f-7f96-4ede-a79b-36dede7af942.json
# Transformed Data uploaded
# rightmove/raw_data/e05a9337-bf32-4711-8e08-9eefffc58a6d.json
# Transformed Data uploaded
# rightmove/raw_data/f60ab2d9-a743-4037-bc97-38d6230d747f.json
# Invalid Data uploaded
# Transformed Data uploaded

# %% [markdown]
# # Testing

# %%
import json
import pandas as pd
import jsonschema
import os
import random

# transformer = RightmoveTransformer()

def load_file_names():
    file_names = os.listdir('data')
    return file_names

def load_data(file_name):
    with open(f'data/{file_name}', 'r') as f:
        data = json.load(f)
    return data

def get_random_numbers(number_of_randoms):
    return random.sample(range(0, 50), number_of_randoms)

def add_random_column(item):
    """
    Adds a random column to each dict in the given list of dicts.
    The column name is a random string of length 5, and the column
    value is a random integer between 1 and 100.
    """
    col_name = "".join(random.choices("abcdefghijklmnopqrstuvwxyz", k=5))
    col_value = random.randint(1, 100)
    item[col_name] = col_value

def remove_random_column(item):
    """
    Removes a random column from each dict in the given list of dicts.
    """
    if len(item) > 1:
        col_name = random.choice(list(item.keys()))
        del item[col_name]

def change_random_value_type(item):
    """
    Changes the data type of a random value in each dict in the given list of dicts.
    The new data type is chosen randomly from float, int, and str.
    """
    col_name = random.choice(list(item.keys()))
    col_value = item[col_name]
    new_type = random.choice([float, int, str])
    if new_type == float:
        item[col_name] = 666
    elif new_type == int:
        item[col_name] = 666
    else:
        item[col_name] = "Test"

def nullify_id(item):
    """
    Sets the value of the 'id' key to None in a random dict in the given list of dicts.
    """
    item['id'] = None
    
def randomize_data(data):

    random_numbers = get_random_numbers(10)
    random_functions = [add_random_column, remove_random_column, change_random_value_type, nullify_id]

    for i, item in enumerate(data):
        if i in random_numbers:
            func = random.choice(random_functions)
            func_name = func.__name__
            print(f"Item {i}, is being randomized by the {func_name} function")
            func(item)
            
    return data

### TEST

# %%
files = fetch_all_files()
file_names = [file.split("/")[-1] for file in files]

# %%
files = fetch_all_files()
file_names = [file.split("/")[-1] for file in files]

# %%
files = fetch_all_files()
file_names = [file.split("/")[-1] for file in files]

for file_name in file_names:
    data = download_data(file_name)
    randomized_data = randomize_data(data)

    valid_data, invalid_data = transformer.validate_data(randomized_data)
    transformed_data = transformer.enforce_columns(valid_data)

    if len(invalid_data) > 0:
        flag = upload_data(invalid_data, file_name, invalid=True)
        print("Invalid Data uploaded")

    flag = upload_data(transformed_data, file_name, invalid=False)
    print("Transformed Data uploaded")
# Out:
# rightmove/raw_data/04fe45d3-a1dc-47b7-ab8a-7db1e393fa05.json
# Item 0, is being randomized by the change_random_value_type function
# Item 11, is being randomized by the nullify_id function
# Item 13, is being randomized by the remove_random_column function
# Item 17, is being randomized by the remove_random_column function
# Item 25, is being randomized by the change_random_value_type function
# Item 32, is being randomized by the change_random_value_type function
# Item 34, is being randomized by the nullify_id function
# Item 36, is being randomized by the nullify_id function
# Item 38, is being randomized by the change_random_value_type function
# Item 40, is being randomized by the add_random_column function
# Item 0 failed because 'Test' is not of type 'integer', 'null'
# Item 11 failed because None is not of type 'integer'
# Item 13 failed because 'lozengeModel' is a required property
# Item 17 failed because 'auction' is a required property
# Item 25 failed because 666 is not of type 'boolean', 'null'
# Item 34 failed because None is not of type 'integer'
# Item 36 failed because None is not of type 'integer'
# Item 38 failed because 666 is not of type 'boolean', 'null'
# Invalid Data uploaded
# Transformed Data uploaded
# rightmove/raw_data/140a0a08-6a85-4b66-8859-09008274e091.json
# Item 9, is being randomized by the change_random_value_type function
# Item 12, is being randomized by the remove_random_column function
# Item 18, is being randomized by the remove_random_column function
# Item 27, is being randomized by the add_random_column function
# Item 30, is being randomized by the remove_random_column function
# Item 31, is being randomized by the nullify_id function
# Item 33, is being randomized by the add_random_column function
# Item 36, is being randomized by the add_random_column function
# Item 42, is being randomized by the nullify_id function
# Item 43, is being randomized by the change_random_value_type function
# Item 9 failed because 666 is not of type 'string', 'null'
# Item 12 failed because 'commercial' is a required property
# Item 18 failed because 'summary' is a required property
# Item 30 failed because 'keywordMatchType' is a required property
# Item 31 failed because None is not of type 'integer'
# Item 42 failed because None is not of type 'integer'
# Item 43 failed because 666 is not of type 'object'
# Invalid Data uploaded
# Transformed Data uploaded
# rightmove/raw_data/1ec51a02-9729-4110-bff1-9b8bdc976306.json
# Item 7, is being randomized by the add_random_column function
# Item 16, is being randomized by the remove_random_column function
# Item 17, is being randomized by the remove_random_column function
# Item 19, is being randomized by the add_random_column function
# Item 25, is being randomized by the change_random_value_type function
# Item 27, is being randomized by the add_random_column function
# Item 28, is being randomized by the remove_random_column function
# Item 30, is being randomized by the remove_random_column function
# Item 31, is being randomized by the add_random_column function
# Item 41, is being randomized by the change_random_value_type function
# Item 16 failed because 'numberOfImages' is a required property
# Item 17 failed because 'listingUpdate' is a required property
# Item 25 failed because 'Test' is not of type 'boolean', 'null'
# Item 28 failed because 'keywordMatchType' is a required property
# Item 30 failed because 'id' is a required property
# Item 41 failed because 666 is not of type 'boolean', 'null'
# Invalid Data uploaded
# Transformed Data uploaded
# rightmove/raw_data/3094a12c-0e2c-410a-9b3e-ae91d3a9d94b.json
# Item 9, is being randomized by the nullify_id function
# Item 28, is being randomized by the nullify_id function
# Item 31, is being randomized by the change_random_value_type function
# Item 33, is being randomized by the change_random_value_type function
# Item 36, is being randomized by the remove_random_column function
# Item 38, is being randomized by the add_random_column function
# Item 41, is being randomized by the change_random_value_type function
# Item 44, is being randomized by the remove_random_column function
# Item 47, is being randomized by the remove_random_column function
# Item 48, is being randomized by the remove_random_column function
# Item 9 failed because None is not of type 'integer'
# Item 28 failed because None is not of type 'integer'
# Item 31 failed because 666 is not of type 'boolean', 'null'
# Item 33 failed because 'Test' is not of type 'integer', 'null'
# Item 36 failed because 'development' is a required property
# Item 44 failed because 'enhancedListing' is a required property
# Item 47 failed because 'addedOrReduced' is a required property
# Item 48 failed because 'enhancedListing' is a required property
# Invalid Data uploaded
# Transformed Data uploaded
# rightmove/raw_data/35fd40b9-c165-4e92-8590-d54af6eb6d4b.json
# Item 6, is being randomized by the remove_random_column function
# Item 9, is being randomized by the add_random_column function
# Item 23, is being randomized by the nullify_id function
# Item 24, is being randomized by the change_random_value_type function
# Item 26, is being randomized by the change_random_value_type function
# Item 27, is being randomized by the change_random_value_type function
# Item 34, is being randomized by the nullify_id function
# Item 36, is being randomized by the change_random_value_type function
# Item 37, is being randomized by the nullify_id function
# Item 45, is being randomized by the add_random_column function
# Item 6 failed because 'propertySubType' is a required property
# Item 23 failed because None is not of type 'integer'
# Item 24 failed because 666 is not of type 'array', 'null'
# Item 26 failed because 'Test' is not of type 'boolean', 'null'
# Item 27 failed because 666 is not of type 'string', 'null'
# Item 34 failed because None is not of type 'integer'
# Item 37 failed because None is not of type 'integer'
# Invalid Data uploaded
# Transformed Data uploaded
# rightmove/raw_data/436a086b-819a-4cb8-a03a-3cc937323f0f.json
# Item 4, is being randomized by the add_random_column function
# Item 16, is being randomized by the remove_random_column function
# Item 22, is being randomized by the nullify_id function
# Item 26, is being randomized by the nullify_id function
# Item 31, is being randomized by the nullify_id function
# Item 34, is being randomized by the add_random_column function
# Item 35, is being randomized by the remove_random_column function
# Item 36, is being randomized by the change_random_value_type function
# Item 42, is being randomized by the nullify_id function
# Item 47, is being randomized by the nullify_id function
# Item 16 failed because 'displaySize' is a required property
# Item 22 failed because None is not of type 'integer'
# Item 26 failed because None is not of type 'integer'
# Item 31 failed because None is not of type 'integer'
# Item 35 failed because 'feesApplyText' is a required property
# Item 42 failed because None is not of type 'integer'
# Item 47 failed because None is not of type 'integer'
# Invalid Data uploaded
# Transformed Data uploaded
# rightmove/raw_data/4e9c6ed9-9030-49a0-bc27-8f948af55b65.json
# Item 3, is being randomized by the remove_random_column function
# Item 10, is being randomized by the change_random_value_type function
# Item 13, is being randomized by the remove_random_column function
# Item 15, is being randomized by the nullify_id function
# Item 21, is being randomized by the change_random_value_type function
# Item 29, is being randomized by the change_random_value_type function
# Item 33, is being randomized by the remove_random_column function
# Item 37, is being randomized by the add_random_column function
# Item 38, is being randomized by the remove_random_column function
# Item 39, is being randomized by the change_random_value_type function
# Item 3 failed because 'lozengeModel' is a required property
# Item 10 failed because 666 is not of type 'object'
# Item 13 failed because 'hasBrandPlus' is a required property
# Item 15 failed because None is not of type 'integer'
# Item 21 failed because 666 is not of type 'string', 'null'
# Item 29 failed because 666 is not of type 'string', 'null'
# Item 33 failed because 'showOnMap' is a required property
# Item 38 failed because 'commercial' is a required property
# Invalid Data uploaded
# Transformed Data uploaded
# rightmove/raw_data/50d4d296-3adb-46fc-9fba-0f5deafba2a2.json
# Item 1, is being randomized by the add_random_column function
# Item 2, is being randomized by the nullify_id function
# Item 3, is being randomized by the nullify_id function
# Item 6, is being randomized by the change_random_value_type function
# Item 8, is being randomized by the nullify_id function
# Item 14, is being randomized by the remove_random_column function
# Item 15, is being randomized by the add_random_column function
# Item 19, is being randomized by the nullify_id function
# Item 23, is being randomized by the add_random_column function
# Item 40, is being randomized by the add_random_column function
# Item 2 failed because None is not of type 'integer'
# Item 3 failed because None is not of type 'integer'
# Item 8 failed because None is not of type 'integer'
# Item 14 failed because 'listingUpdate' is a required property
# Item 19 failed because None is not of type 'integer'
# Invalid Data uploaded
# Transformed Data uploaded
# rightmove/raw_data/596e7849-2eb2-4a5f-908b-ac59db290f75.json
# Item 5, is being randomized by the change_random_value_type function
# Item 13, is being randomized by the add_random_column function
# Item 15, is being randomized by the nullify_id function
# Item 16, is being randomized by the add_random_column function
# Item 17, is being randomized by the add_random_column function
# Item 19, is being randomized by the nullify_id function
# Item 23, is being randomized by the change_random_value_type function
# Item 31, is being randomized by the remove_random_column function
# Item 32, is being randomized by the remove_random_column function
# Item 34, is being randomized by the change_random_value_type function
# Item 5 failed because 'Test' is not of type 'object'
# Item 15 failed because None is not of type 'integer'
# Item 19 failed because None is not of type 'integer'
# Item 23 failed because 666 is not of type 'string', 'null'
# Item 31 failed because 'propertyTypeFullDescription' is a required property
# Item 32 failed because 'numberOfVirtualTours' is a required property
# Invalid Data uploaded
# Transformed Data uploaded
# rightmove/raw_data/6d060173-9238-4d7f-b424-97c063fabe1d.json
# Item 6, is being randomized by the nullify_id function
# Item 14, is being randomized by the change_random_value_type function
# Item 19, is being randomized by the add_random_column function
# Item 20, is being randomized by the add_random_column function
# Item 22, is being randomized by the change_random_value_type function
# Item 24, is being randomized by the change_random_value_type function
# Item 27, is being randomized by the add_random_column function
# Item 29, is being randomized by the add_random_column function
# Item 32, is being randomized by the change_random_value_type function
# Item 48, is being randomized by the nullify_id function
# Item 6 failed because None is not of type 'integer'
# Item 22 failed because 666 is not of type 'boolean', 'null'
# Item 24 failed because 666 is not of type 'string', 'null'
# Item 32 failed because 'Test' is not of type 'integer', 'null'
# Item 48 failed because None is not of type 'integer'
# Invalid Data uploaded
# Transformed Data uploaded
# rightmove/raw_data/7e56578f-5991-4d3f-8a72-e7507501cdbc.json
# Item 2, is being randomized by the remove_random_column function
# Item 4, is being randomized by the change_random_value_type function
# Item 16, is being randomized by the change_random_value_type function
# Item 19, is being randomized by the add_random_column function
# Item 22, is being randomized by the add_random_column function
# Item 25, is being randomized by the change_random_value_type function
# Item 30, is being randomized by the add_random_column function
# Item 39, is being randomized by the remove_random_column function
# Item 43, is being randomized by the remove_random_column function
# Item 47, is being randomized by the remove_random_column function
# Item 2 failed because 'hasBrandPlus' is a required property
# Item 4 failed because 666 is not of type 'object'
# Item 16 failed because 666 is not of type 'boolean', 'null'
# Item 25 failed because 666 is not of type 'string', 'null'
# Item 39 failed because 'displayStatus' is a required property
# Item 43 failed because 'location' is a required property
# Item 47 failed because 'numberOfImages' is a required property
# Invalid Data uploaded
# Transformed Data uploaded
# rightmove/raw_data/83fd30f0-c08c-4adb-8e6a-4e00292b40e7.json
# Item 3, is being randomized by the nullify_id function
# Item 4, is being randomized by the add_random_column function
# Item 7, is being randomized by the remove_random_column function
# Item 12, is being randomized by the change_random_value_type function
# Item 17, is being randomized by the remove_random_column function
# Item 18, is being randomized by the change_random_value_type function
# Item 32, is being randomized by the add_random_column function
# Item 35, is being randomized by the remove_random_column function
# Item 40, is being randomized by the remove_random_column function
# Item 42, is being randomized by the remove_random_column function
# Item 3 failed because None is not of type 'integer'
# Item 7 failed because 'feesApply' is a required property
# Item 12 failed because 666 is not of type 'boolean', 'null'
# Item 17 failed because 'development' is a required property
# Item 35 failed because 'summary' is a required property
# Item 40 failed because 'propertyTypeFullDescription' is a required property
# Item 42 failed because 'countryCode' is a required property
# Invalid Data uploaded
# Transformed Data uploaded
# rightmove/raw_data/86a4e58a-8f68-4834-850b-7b5fe257abd5.json
# Item 0, is being randomized by the nullify_id function
# Item 1, is being randomized by the remove_random_column function
# Item 5, is being randomized by the remove_random_column function
# Item 6, is being randomized by the nullify_id function
# Item 9, is being randomized by the nullify_id function
# Item 10, is being randomized by the nullify_id function
# Item 13, is being randomized by the nullify_id function
# Item 22, is being randomized by the add_random_column function
# Item 27, is being randomized by the change_random_value_type function
# Item 49, is being randomized by the add_random_column function
# Item 0 failed because None is not of type 'integer'
# Item 1 failed because 'numberOfFloorplans' is a required property
# Item 6 failed because None is not of type 'integer'
# Item 9 failed because None is not of type 'integer'
# Item 10 failed because None is not of type 'integer'
# Item 13 failed because None is not of type 'integer'
# Item 27 failed because 666 is not of type 'string', 'null'
# Invalid Data uploaded
# Transformed Data uploaded
# rightmove/raw_data/8cd8cee0-ea11-4b13-980c-625908c33dc9.json
# Item 0, is being randomized by the change_random_value_type function
# Item 1, is being randomized by the nullify_id function
# Item 2, is being randomized by the change_random_value_type function
# Item 8, is being randomized by the change_random_value_type function
# Item 11, is being randomized by the change_random_value_type function
# Item 21, is being randomized by the change_random_value_type function
# Item 35, is being randomized by the remove_random_column function
# Item 42, is being randomized by the change_random_value_type function
# Item 43, is being randomized by the add_random_column function
# Item 45, is being randomized by the nullify_id function
# Item 0 failed because 666 is not of type 'object'
# Item 1 failed because None is not of type 'integer'
# Item 2 failed because 666 is not of type 'array', 'null'
# Item 8 failed because 'Test' is not of type 'object'
# Item 11 failed because 666 is not of type 'boolean', 'null'
# Item 21 failed because 666 is not of type 'string', 'null'
# Item 35 failed because 'numberOfVirtualTours' is a required property
# Item 42 failed because 666 is not of type 'string', 'null'
# Item 45 failed because None is not of type 'integer'
# Invalid Data uploaded
# Transformed Data uploaded
# rightmove/raw_data/907c096f-79b7-4b71-a869-8f9a367d0fef.json
# Item 9, is being randomized by the nullify_id function
# Item 18, is being randomized by the nullify_id function
# Item 20, is being randomized by the change_random_value_type function
# Item 21, is being randomized by the add_random_column function
# Item 22, is being randomized by the remove_random_column function
# Item 27, is being randomized by the change_random_value_type function
# Item 28, is being randomized by the remove_random_column function
# Item 41, is being randomized by the nullify_id function
# Item 43, is being randomized by the change_random_value_type function
# Item 49, is being randomized by the add_random_column function
# Item 9 failed because None is not of type 'integer'
# Item 18 failed because None is not of type 'integer'
# Item 20 failed because 666 is not of type 'object'
# Item 22 failed because 'saved' is a required property
# Item 27 failed because 666 is not of type 'boolean', 'null'
# Item 28 failed because 'listingUpdate' is a required property
# Item 41 failed because None is not of type 'integer'
# Item 43 failed because 666 is not of type 'boolean', 'null'
# Invalid Data uploaded
# Transformed Data uploaded
# rightmove/raw_data/94fbed03-016f-4079-90bf-d3231bbcc6da.json
# Item 1, is being randomized by the nullify_id function
# Item 10, is being randomized by the nullify_id function
# Item 11, is being randomized by the remove_random_column function
# Item 12, is being randomized by the remove_random_column function
# Item 18, is being randomized by the nullify_id function
# Item 23, is being randomized by the remove_random_column function
# Item 42, is being randomized by the change_random_value_type function
# Item 43, is being randomized by the change_random_value_type function
# Item 46, is being randomized by the add_random_column function
# Item 49, is being randomized by the change_random_value_type function
# Item 1 failed because None is not of type 'integer'
# Item 10 failed because None is not of type 'integer'
# Item 11 failed because 'listingUpdate' is a required property
# Item 12 failed because 'propertyUrl' is a required property
# Item 18 failed because None is not of type 'integer'
# Item 23 failed because 'id' is a required property
# Item 43 failed because 666 is not of type 'string', 'null'
# Item 49 failed because 'Test' is not of type 'boolean', 'null'
# Invalid Data uploaded
# Transformed Data uploaded
# rightmove/raw_data/9c314476-fafa-448c-97c4-1ca09da569df.json
# Item 5, is being randomized by the remove_random_column function
# Item 6, is being randomized by the add_random_column function
# Item 9, is being randomized by the remove_random_column function
# Item 18, is being randomized by the change_random_value_type function
# Item 19, is being randomized by the change_random_value_type function
# Item 28, is being randomized by the nullify_id function
# Item 33, is being randomized by the add_random_column function
# Item 34, is being randomized by the add_random_column function
# Item 36, is being randomized by the nullify_id function
# Item 46, is being randomized by the remove_random_column function
# Item 5 failed because 'addedOrReduced' is a required property
# Item 9 failed because 'propertyUrl' is a required property
# Item 18 failed because 666 is not of type 'string', 'null'
# Item 19 failed because 'Test' is not of type 'object'
# Item 28 failed because None is not of type 'integer'
# Item 36 failed because None is not of type 'integer'
# Item 46 failed because 'productLabel' is a required property
# Invalid Data uploaded
# Transformed Data uploaded
# rightmove/raw_data/a6c34e9c-df4b-4dd0-b23c-568c8979779c.json
# Item 15, is being randomized by the nullify_id function
# Item 17, is being randomized by the change_random_value_type function
# Item 19, is being randomized by the add_random_column function
# Item 21, is being randomized by the add_random_column function
# Item 22, is being randomized by the nullify_id function
# Item 23, is being randomized by the remove_random_column function
# Item 30, is being randomized by the change_random_value_type function
# Item 37, is being randomized by the nullify_id function
# Item 45, is being randomized by the remove_random_column function
# Item 49, is being randomized by the change_random_value_type function
# Item 15 failed because None is not of type 'integer'
# Item 17 failed because 'Test' is not of type 'object'
# Item 22 failed because None is not of type 'integer'
# Item 37 failed because None is not of type 'integer'
# Item 45 failed because 'saved' is a required property
# Invalid Data uploaded
# Transformed Data uploaded
# rightmove/raw_data/ac568ace-9f07-45d3-a3c8-c2e975444e1e.json
# Item 1, is being randomized by the change_random_value_type function
# Item 3, is being randomized by the change_random_value_type function
# Item 7, is being randomized by the nullify_id function
# Item 10, is being randomized by the add_random_column function
# Item 25, is being randomized by the change_random_value_type function
# Item 28, is being randomized by the add_random_column function
# Item 29, is being randomized by the nullify_id function
# Item 30, is being randomized by the add_random_column function
# Item 38, is being randomized by the add_random_column function
# Item 49, is being randomized by the change_random_value_type function
# Item 1 failed because 666 is not of type 'string', 'null'
# Item 7 failed because None is not of type 'integer'
# Item 29 failed because None is not of type 'integer'
# Item 49 failed because 666 is not of type 'string', 'null'
# Invalid Data uploaded
# Transformed Data uploaded
# rightmove/raw_data/ae9d43ce-f583-4418-b42c-ef8171d2e575.json
# Item 1, is being randomized by the nullify_id function
# Item 2, is being randomized by the change_random_value_type function
# Item 5, is being randomized by the add_random_column function
# Item 15, is being randomized by the change_random_value_type function
# Item 21, is being randomized by the add_random_column function
# Item 23, is being randomized by the change_random_value_type function
# Item 28, is being randomized by the remove_random_column function
# Item 30, is being randomized by the add_random_column function
# Item 35, is being randomized by the change_random_value_type function
# Item 37, is being randomized by the nullify_id function
# Item 1 failed because None is not of type 'integer'
# Item 15 failed because 666 is not of type 'boolean', 'null'
# Item 23 failed because 666 is not of type 'string', 'null'
# Item 28 failed because 'propertyImages' is a required property
# Item 35 failed because 666 is not of type 'string', 'null'
# Item 37 failed because None is not of type 'integer'
# Invalid Data uploaded
# Transformed Data uploaded
# rightmove/raw_data/bb5cdb41-2aa1-4370-af92-034721e2e810.json
# Item 6, is being randomized by the remove_random_column function
# Item 13, is being randomized by the change_random_value_type function
# Item 17, is being randomized by the add_random_column function
# Item 18, is being randomized by the add_random_column function
# Item 27, is being randomized by the remove_random_column function
# Item 35, is being randomized by the nullify_id function
# Item 38, is being randomized by the add_random_column function
# Item 44, is being randomized by the change_random_value_type function
# Item 48, is being randomized by the add_random_column function
# Item 49, is being randomized by the add_random_column function
# Item 6 failed because 'auction' is a required property
# Item 13 failed because 666 is not of type 'string', 'null'
# Item 27 failed because 'feature_list' is a required property
# Item 35 failed because None is not of type 'integer'
# Invalid Data uploaded
# Transformed Data uploaded
# rightmove/raw_data/d2c7ddba-0932-4b05-867e-bf5e2c3c2b27.json
# Item 3, is being randomized by the nullify_id function
# Item 7, is being randomized by the change_random_value_type function
# Item 18, is being randomized by the nullify_id function
# Item 20, is being randomized by the change_random_value_type function
# Item 21, is being randomized by the add_random_column function
# Item 24, is being randomized by the add_random_column function
# Item 27, is being randomized by the change_random_value_type function
# Item 33, is being randomized by the change_random_value_type function
# Item 35, is being randomized by the nullify_id function
# Item 40, is being randomized by the add_random_column function
# Item 3 failed because None is not of type 'integer'
# Item 18 failed because None is not of type 'integer'
# Item 20 failed because 666 is not of type 'string', 'null'
# Item 27 failed because 666 is not of type 'boolean', 'null'
# Item 33 failed because 666 is not of type 'boolean', 'null'
# Item 35 failed because None is not of type 'integer'
# Invalid Data uploaded
# Transformed Data uploaded
# rightmove/raw_data/d609f820-d70c-48c8-a048-eb190b267ca1.json
# Item 1, is being randomized by the change_random_value_type function
# Item 3, is being randomized by the nullify_id function
# Item 18, is being randomized by the nullify_id function
# Item 19, is being randomized by the change_random_value_type function
# Item 24, is being randomized by the change_random_value_type function
# Item 39, is being randomized by the add_random_column function
# Item 40, is being randomized by the remove_random_column function
# Item 42, is being randomized by the nullify_id function
# Item 44, is being randomized by the change_random_value_type function
# Item 49, is being randomized by the nullify_id function
# Item 1 failed because 'Test' is not of type 'boolean', 'null'
# Item 3 failed because None is not of type 'integer'
# Item 18 failed because None is not of type 'integer'
# Item 19 failed because 'Test' is not of type 'integer'
# Item 24 failed because 666 is not of type 'boolean', 'null'
# Item 40 failed because 'feesApply' is a required property
# Item 42 failed because None is not of type 'integer'
# Item 49 failed because None is not of type 'integer'
# Invalid Data uploaded
# Transformed Data uploaded
# rightmove/raw_data/dc6903f6-0392-4e2e-b147-401cb7866867.json
# Item 1, is being randomized by the nullify_id function
# Item 9, is being randomized by the add_random_column function
# Item 15, is being randomized by the change_random_value_type function
# Item 19, is being randomized by the remove_random_column function
# Item 23, is being randomized by the change_random_value_type function
# Item 30, is being randomized by the change_random_value_type function
# Item 32, is being randomized by the nullify_id function
# Item 36, is being randomized by the add_random_column function
# Item 39, is being randomized by the nullify_id function
# Item 40, is being randomized by the change_random_value_type function
# Item 1 failed because None is not of type 'integer'
# Item 15 failed because 'Test' is not of type 'boolean', 'null'
# Item 19 failed because 'formattedDistance' is a required property
# Item 23 failed because 666 is not of type 'string', 'null'
# Item 30 failed because 666 is not of type 'string', 'null'
# Item 32 failed because None is not of type 'integer'
# Item 39 failed because None is not of type 'integer'
# Item 40 failed because 666 is not of type 'string', 'null'
# Invalid Data uploaded
# Transformed Data uploaded
# rightmove/raw_data/df0ef68f-7f96-4ede-a79b-36dede7af942.json
# Item 0, is being randomized by the add_random_column function
# Item 5, is being randomized by the add_random_column function
# Item 7, is being randomized by the change_random_value_type function
# Item 16, is being randomized by the remove_random_column function
# Item 18, is being randomized by the remove_random_column function
# Item 40, is being randomized by the change_random_value_type function
# Item 43, is being randomized by the change_random_value_type function
# Item 45, is being randomized by the change_random_value_type function
# Item 46, is being randomized by the nullify_id function
# Item 47, is being randomized by the add_random_column function
# Item 7 failed because 666 is not of type 'string', 'null'
# Item 16 failed because 'feature_list' is a required property
# Item 18 failed because 'price' is a required property
# Item 40 failed because 666 is not of type 'string', 'null'
# Item 43 failed because 666 is not of type 'boolean', 'null'
# Item 45 failed because 666 is not of type 'string', 'null'
# Item 46 failed because None is not of type 'integer'
# Invalid Data uploaded
# Transformed Data uploaded
# rightmove/raw_data/e05a9337-bf32-4711-8e08-9eefffc58a6d.json
# Item 3, is being randomized by the remove_random_column function
# Item 6, is being randomized by the change_random_value_type function
# Item 8, is being randomized by the nullify_id function
# Item 12, is being randomized by the change_random_value_type function
# Item 17, is being randomized by the nullify_id function
# Item 22, is being randomized by the remove_random_column function
# Item 29, is being randomized by the nullify_id function
# Item 37, is being randomized by the nullify_id function
# Item 40, is being randomized by the add_random_column function
# Item 49, is being randomized by the change_random_value_type function
# Item 6 failed because 666 is not of type 'string', 'null'
# Item 8 failed because None is not of type 'integer'
# Item 12 failed because 666 is not of type 'object'
# Item 17 failed because None is not of type 'integer'
# Item 22 failed because 'residential' is a required property
# Item 29 failed because None is not of type 'integer'
# Item 37 failed because None is not of type 'integer'
# Item 49 failed because 'Test' is not of type 'boolean', 'null'
# Invalid Data uploaded
# Transformed Data uploaded
# rightmove/raw_data/f60ab2d9-a743-4037-bc97-38d6230d747f.json
# Item 0, is being randomized by the remove_random_column function
# Item 2, is being randomized by the nullify_id function
# Item 11, is being randomized by the remove_random_column function
# Item 13, is being randomized by the nullify_id function
# Item 20, is being randomized by the nullify_id function
# Item 22, is being randomized by the remove_random_column function
# Item 23, is being randomized by the add_random_column function
# Item 24, is being randomized by the nullify_id function
# Item 44, is being randomized by the add_random_column function
# Item 48, is being randomized by the change_random_value_type function
# Item 0 failed because 'productLabel' is a required property
# Item 2 failed because None is not of type 'integer'
# Item 11 failed because 'bathrooms' is a required property
# Item 13 failed because None is not of type 'integer'
# Item 20 failed because None is not of type 'integer'
# Item 22 failed because 'showOnMap' is a required property
# Item 24 failed because None is not of type 'integer'
# Item 48 failed because 666 is not of type 'boolean', 'null'
# Invalid Data uploaded
# Transformed Data uploaded

# %%
data = download_data(file_names[0])
randomized_data = randomize_data(data)

valid_data, invalid_data = transformer.validate_data(randomized_data)
transformed_data = transformer.enforce_columns(valid_data)

if len(invalid_data) > 0:
    flag = upload_data(invalid_data, file_name, invalid=True)
    print("Invalid Data uploaded")

flag = upload_data(transformed_data, file_name, invalid=False)
print("Transformed Data uploaded")
# Out:
# rightmove/raw_data_json_test/14c71934-8f7d-40af-a161-abece209567e.json
# Item 1, is being randomized by the remove_random_column function
# Item 12, is being randomized by the change_random_value_type function
# Item 16, is being randomized by the change_random_value_type function
# Item 17, is being randomized by the remove_random_column function
# Item 22, is being randomized by the nullify_id function
# Item 25, is being randomized by the add_random_column function
# Item 30, is being randomized by the nullify_id function
# Item 39, is being randomized by the change_random_value_type function
# Item 41, is being randomized by the remove_random_column function
# Item 47, is being randomized by the add_random_column function
# Item 16 failed because 666 is not of type 'string', 'null'
# Item 17 failed because 'residential' is a required property
# Item 22 failed because None is not of type 'integer'
# Item 30 failed because None is not of type 'integer'
# Item 39 failed because 'Test' is not of type 'object'
# Item 41 failed because 'productLabel' is a required property
# 6
# Invalid Data uploaded
# Transformed Data uploaded
