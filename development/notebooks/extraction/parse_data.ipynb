# %%
import pandas as pd

# %%
df = pd.read_json("../../real_estate_extraction/data.jsonlines", lines=True)

# %%
df.feature_list.iloc[0]
# Out:
# 'No Agent Fees,Students Can Enquire,Property Reference Number 1611326'

# %%
df
# Out:
#            id  bedrooms  bathrooms  numberOfImages  numberOfFloorplans  \
# 0   130809395         1        2.0              20                   0
# 1   130388585         1        1.0               7                   0
# 2   130375976         2        1.0               8                   0
# 3   130303826         2        2.0              11                   0
# 4   130180496         4        2.0               9                   0
# 5   130180499         2        1.0              11                   0
# 6   131240282         1        1.0               6                   0
# 7   130453754         2        2.0               8                   0
# 8   130272461         2        0.0               9                   0
# 9   130535627         2        1.0              11                   0
# 10  130394303         1        1.0              12                   0
# 11  131404829         1        1.0               8                   0
# ...
